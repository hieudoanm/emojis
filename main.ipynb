# %%
import os
import json
import requests


# API endpoint
API_URL = "https://api.github.com/emojis"


# Output files
JSON_FILE = "emojis.json"
EMOJIS_LIST_FILE = "emojis_list.txt"
EMOJIS_IMAGE_FILE = "emojis_image.txt"
IMAGES_DIR = "images"


# Ensure images directory exists
os.makedirs(IMAGES_DIR, exist_ok=True)


def fetch_emojis():
    """Fetch emojis from GitHub API and return as JSON"""
    print("Fetching emojis from GitHub API...")
    response = requests.get(API_URL)
    response.raise_for_status()
    return response.json()


def save_json(data, filename):
    """Save JSON data to a file"""
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(data, f, indent=4, ensure_ascii=False)
    print(f"Saved JSON data to {filename}")


def save_list(data, filename):
    """Save all keys (emoji names) to a text file with :key: format"""
    keys: list[str] = sorted(data.keys())
    formatted_keys = [
        f"- :{key}: `:{key}:`" for key in keys
    ]  # Wrap each key with colons
    with open(filename, "w", encoding="utf-8") as f:
        f.write("\n".join(formatted_keys))
    print(f"Saved all emoji keys (with colons) to {filename}")


def save_images(data, filename):
    """Save all keys (emoji names) to a text file with :key: format"""
    keys: list[str] = sorted(data.keys())
    formatted_keys = [
        f"![{key}](./images/{key}.png)" for key in keys
    ]  # Wrap each key with colons
    with open(filename, "w", encoding="utf-8") as f:
        f.write("\n".join(formatted_keys))
    print(f"Saved all emoji keys (with colons) to {filename}")


def download_images(data, skip_existing=True):
    """
    Download all emoji images from GitHub.

    Args:
        data (dict): Mapping of emoji name to image URL.
        skip_existing (bool): If True, skip downloading files that already exist.
    """
    print("Downloading emoji images...")
    for name, url in data.items():
        image_path = os.path.join(IMAGES_DIR, f"{name}.png")

        # Skip if file exists
        if skip_existing and os.path.exists(image_path):
            print(f"Skipping (already exists): {name}")
            continue

        try:
            img_data = requests.get(url, timeout=10)
            img_data.raise_for_status()
            with open(image_path, "wb") as img_file:
                img_file.write(img_data.content)
            print(f"Downloaded: {name}")
        except Exception as e:
            print(f"Failed to download {name}: {e}")


# Fetch data
emojis = fetch_emojis()

# Save JSON
save_json(emojis, JSON_FILE)

# Save keys to text file
save_list(emojis, EMOJIS_LIST_FILE)

# Save image markdown links to text file
save_images(emojis, EMOJIS_IMAGE_FILE)

# Download images
download_images(emojis)
# Out:
# Fetching emojis from GitHub API...
# Saved JSON data to emojis.json
# Saved all emoji keys (with colons) to emojis_list.txt
# Saved all emoji keys (with colons) to emojis_image.txt
# Downloading emoji images...
# Skipping (already exists): +1
# Skipping (already exists): -1
# Skipping (already exists): 100
# Skipping (already exists): 1234
# Skipping (already exists): 1st_place_medal
# Skipping (already exists): 2nd_place_medal
# Skipping (already exists): 3rd_place_medal
# Skipping (already exists): 8ball
# Skipping (already exists): a
# Skipping (already exists): ab
# Skipping (already exists): abacus
# Skipping (already exists): abc
# Skipping (already exists): abcd
# Skipping (already exists): accept
# Skipping (already exists): accessibility
# Skipping (already exists): accordion
# Skipping (already exists): adhesive_bandage
# Skipping (already exists): adult
# Skipping (already exists): aerial_tramway
# Skipping (already exists): afghanistan
# Skipping (already exists): airplane
# Skipping (already exists): aland_islands
# Skipping (already exists): alarm_clock
# Skipping (already exists): albania
# Skipping (already exists): alembic
# Skipping (already exists): algeria
# Skipping (already exists): alien
# Skipping (already exists): ambulance
# Skipping (already exists): american_samoa
# Skipping (already exists): amphora
# Skipping (already exists): anatomical_heart
# Skipping (already exists): anchor
# Skipping (already exists): andorra
# Skipping (already exists): angel
# Skipping (already exists): anger
# Skipping (already exists): angola
# Skipping (already exists): angry
# Skipping (already exists): anguilla
# Skipping (already exists): anguished
# Skipping (already exists): ant
# Skipping (already exists): antarctica
# Skipping (already exists): antigua_barbuda
# Skipping (already exists): apple
# Skipping (already exists): aquarius
# Skipping (already exists): argentina
# Skipping (already exists): aries
# Skipping (already exists): armenia
# Skipping (already exists): arrow_backward
# Skipping (already exists): arrow_double_down
# Skipping (already exists): arrow_double_up
# Skipping (already exists): arrow_down
# Skipping (already exists): arrow_down_small
# Skipping (already exists): arrow_forward
# Skipping (already exists): arrow_heading_down
# Skipping (already exists): arrow_heading_up
# Skipping (already exists): arrow_left
# Skipping (already exists): arrow_lower_left
# Skipping (already exists): arrow_lower_right
# Skipping (already exists): arrow_right
# Skipping (already exists): arrow_right_hook
# Skipping (already exists): arrow_up
# Skipping (already exists): arrow_up_down
# Skipping (already exists): arrow_up_small
# Skipping (already exists): arrow_upper_left
# Skipping (already exists): arrow_upper_right
# Skipping (already exists): arrows_clockwise
# Skipping (already exists): arrows_counterclockwise
# Skipping (already exists): art
# Skipping (already exists): articulated_lorry
# Skipping (already exists): artificial_satellite
# Skipping (already exists): artist
# Skipping (already exists): aruba
# Skipping (already exists): ascension_island
# Skipping (already exists): asterisk
# Skipping (already exists): astonished
# Skipping (already exists): astronaut
# Skipping (already exists): athletic_shoe
# Skipping (already exists): atm
# Skipping (already exists): atom
# Skipping (already exists): atom_symbol
# Skipping (already exists): australia
# Skipping (already exists): austria
# Skipping (already exists): auto_rickshaw
# Skipping (already exists): avocado
# Skipping (already exists): axe
# Skipping (already exists): azerbaijan
# Skipping (already exists): b
# Skipping (already exists): baby
# Skipping (already exists): baby_bottle
# Skipping (already exists): baby_chick
# Skipping (already exists): baby_symbol
# Skipping (already exists): back
# Skipping (already exists): bacon
# Skipping (already exists): badger
# Skipping (already exists): badminton
# Skipping (already exists): bagel
# Skipping (already exists): baggage_claim
# Skipping (already exists): baguette_bread
# Skipping (already exists): bahamas
# Skipping (already exists): bahrain
# Skipping (already exists): balance_scale
# Skipping (already exists): bald_man
# Skipping (already exists): bald_woman
# Skipping (already exists): ballet_shoes
# Skipping (already exists): balloon
# Skipping (already exists): ballot_box
# Skipping (already exists): ballot_box_with_check
# Skipping (already exists): bamboo
# Skipping (already exists): banana
# Skipping (already exists): bangbang
# Skipping (already exists): bangladesh
# Skipping (already exists): banjo
# Skipping (already exists): bank
# Skipping (already exists): bar_chart
# Skipping (already exists): barbados
# Skipping (already exists): barber
# Skipping (already exists): baseball
# Skipping (already exists): basecamp
# Skipping (already exists): basecampy
# Skipping (already exists): basket
# Skipping (already exists): basketball
# Skipping (already exists): basketball_man
# Skipping (already exists): basketball_woman
# Skipping (already exists): bat
# Skipping (already exists): bath
# Skipping (already exists): bathtub
# Skipping (already exists): battery
# Skipping (already exists): beach_umbrella
# Skipping (already exists): beans
# Skipping (already exists): bear
# Skipping (already exists): bearded_person
# Skipping (already exists): beaver
# Skipping (already exists): bed
# Skipping (already exists): bee
# Skipping (already exists): beer
# Skipping (already exists): beers
# Skipping (already exists): beetle
# Skipping (already exists): beginner
# Skipping (already exists): belarus
# Skipping (already exists): belgium
# Skipping (already exists): belize
# Skipping (already exists): bell
# Skipping (already exists): bell_pepper
# Skipping (already exists): bellhop_bell
# Skipping (already exists): benin
# Skipping (already exists): bento
# Skipping (already exists): bermuda
# Skipping (already exists): beverage_box
# Skipping (already exists): bhutan
# Skipping (already exists): bicyclist
# Skipping (already exists): bike
# Skipping (already exists): biking_man
# Skipping (already exists): biking_woman
# Skipping (already exists): bikini
# Skipping (already exists): billed_cap
# Skipping (already exists): biohazard
# Skipping (already exists): bird
# Skipping (already exists): birthday
# Skipping (already exists): bison
# Skipping (already exists): biting_lip
# Skipping (already exists): black_bird
# Skipping (already exists): black_cat
# Skipping (already exists): black_circle
# Skipping (already exists): black_flag
# Skipping (already exists): black_heart
# Skipping (already exists): black_joker
# Skipping (already exists): black_large_square
# Skipping (already exists): black_medium_small_square
# Skipping (already exists): black_medium_square
# Skipping (already exists): black_nib
# Skipping (already exists): black_small_square
# Skipping (already exists): black_square_button
# Skipping (already exists): blond_haired_man
# Skipping (already exists): blond_haired_person
# Skipping (already exists): blond_haired_woman
# Skipping (already exists): blonde_woman
# Skipping (already exists): blossom
# Skipping (already exists): blowfish
# Skipping (already exists): blue_book
# Skipping (already exists): blue_car
# Skipping (already exists): blue_heart
# Skipping (already exists): blue_square
# Skipping (already exists): blueberries
# Skipping (already exists): blush
# Skipping (already exists): boar
# Skipping (already exists): boat
# Skipping (already exists): bolivia
# Skipping (already exists): bomb
# Skipping (already exists): bone
# Skipping (already exists): book
# Skipping (already exists): bookmark
# Skipping (already exists): bookmark_tabs
# Skipping (already exists): books
# Skipping (already exists): boom
# Skipping (already exists): boomerang
# Skipping (already exists): boot
# Skipping (already exists): bosnia_herzegovina
# Skipping (already exists): botswana
# Skipping (already exists): bouncing_ball_man
# Skipping (already exists): bouncing_ball_person
# Skipping (already exists): bouncing_ball_woman
# Skipping (already exists): bouquet
# Skipping (already exists): bouvet_island
# Skipping (already exists): bow
# Skipping (already exists): bow_and_arrow
# Skipping (already exists): bowing_man
# Skipping (already exists): bowing_woman
# Skipping (already exists): bowl_with_spoon
# Skipping (already exists): bowling
# Skipping (already exists): bowtie
# Skipping (already exists): boxing_glove
# Skipping (already exists): boy
# Skipping (already exists): brain
# Skipping (already exists): brazil
# Skipping (already exists): bread
# Skipping (already exists): breast_feeding
# Skipping (already exists): bricks
# Skipping (already exists): bride_with_veil
# Skipping (already exists): bridge_at_night
# Skipping (already exists): briefcase
# Skipping (already exists): british_indian_ocean_territory
# Skipping (already exists): british_virgin_islands
# Skipping (already exists): broccoli
# Skipping (already exists): broken_heart
# Skipping (already exists): broom
# Skipping (already exists): brown_circle
# Skipping (already exists): brown_heart
# Skipping (already exists): brown_square
# Skipping (already exists): brunei
# Skipping (already exists): bubble_tea
# Skipping (already exists): bubbles
# Skipping (already exists): bucket
# Skipping (already exists): bug
# Skipping (already exists): building_construction
# Skipping (already exists): bulb
# Skipping (already exists): bulgaria
# Skipping (already exists): bullettrain_front
# Skipping (already exists): bullettrain_side
# Skipping (already exists): burkina_faso
# Skipping (already exists): burrito
# Skipping (already exists): burundi
# Skipping (already exists): bus
# Skipping (already exists): business_suit_levitating
# Skipping (already exists): busstop
# Skipping (already exists): bust_in_silhouette
# Skipping (already exists): busts_in_silhouette
# Skipping (already exists): butter
# Skipping (already exists): butterfly
# Skipping (already exists): cactus
# Skipping (already exists): cake
# Skipping (already exists): calendar
# Skipping (already exists): call_me_hand
# Skipping (already exists): calling
# Skipping (already exists): cambodia
# Skipping (already exists): camel
# Skipping (already exists): camera
# Skipping (already exists): camera_flash
# Skipping (already exists): cameroon
# Skipping (already exists): camping
# Skipping (already exists): canada
# Skipping (already exists): canary_islands
# Skipping (already exists): cancer
# Skipping (already exists): candle
# Skipping (already exists): candy
# Skipping (already exists): canned_food
# Skipping (already exists): canoe
# Skipping (already exists): cape_verde
# Skipping (already exists): capital_abcd
# Skipping (already exists): capricorn
# Skipping (already exists): car
# Skipping (already exists): card_file_box
# Skipping (already exists): card_index
# Skipping (already exists): card_index_dividers
# Skipping (already exists): caribbean_netherlands
# Skipping (already exists): carousel_horse
# Skipping (already exists): carpentry_saw
# Skipping (already exists): carrot
# Skipping (already exists): cartwheeling
# Skipping (already exists): cat
# Skipping (already exists): cat2
# Skipping (already exists): cayman_islands
# Skipping (already exists): cd
# Skipping (already exists): central_african_republic
# Skipping (already exists): ceuta_melilla
# Skipping (already exists): chad
# Skipping (already exists): chains
# Skipping (already exists): chair
# Skipping (already exists): champagne
# Skipping (already exists): chart
# Skipping (already exists): chart_with_downwards_trend
# Skipping (already exists): chart_with_upwards_trend
# Skipping (already exists): checkered_flag
# Skipping (already exists): cheese
# Skipping (already exists): cherries
# Skipping (already exists): cherry_blossom
# Skipping (already exists): chess_pawn
# Skipping (already exists): chestnut
# Skipping (already exists): chicken
# Skipping (already exists): child
# Skipping (already exists): children_crossing
# Skipping (already exists): chile
# Skipping (already exists): chipmunk
# Skipping (already exists): chocolate_bar
# Skipping (already exists): chopsticks
# Skipping (already exists): christmas_island
# Skipping (already exists): christmas_tree
# Skipping (already exists): church
# Skipping (already exists): cinema
# Skipping (already exists): circus_tent
# Skipping (already exists): city_sunrise
# Skipping (already exists): city_sunset
# Skipping (already exists): cityscape
# Skipping (already exists): cl
# Skipping (already exists): clamp
# Skipping (already exists): clap
# Skipping (already exists): clapper
# Skipping (already exists): classical_building
# Skipping (already exists): climbing
# Skipping (already exists): climbing_man
# Skipping (already exists): climbing_woman
# Skipping (already exists): clinking_glasses
# Skipping (already exists): clipboard
# Skipping (already exists): clipperton_island
# Skipping (already exists): clock1
# Skipping (already exists): clock10
# Skipping (already exists): clock1030
# Skipping (already exists): clock11
# Skipping (already exists): clock1130
# Skipping (already exists): clock12
# Skipping (already exists): clock1230
# Skipping (already exists): clock130
# Skipping (already exists): clock2
# Skipping (already exists): clock230
# Skipping (already exists): clock3
# Skipping (already exists): clock330
# Skipping (already exists): clock4
# Skipping (already exists): clock430
# Skipping (already exists): clock5
# Skipping (already exists): clock530
# Skipping (already exists): clock6
# Skipping (already exists): clock630
# Skipping (already exists): clock7
# Skipping (already exists): clock730
# Skipping (already exists): clock8
# Skipping (already exists): clock830
# Skipping (already exists): clock9
# Skipping (already exists): clock930
# Skipping (already exists): closed_book
# Skipping (already exists): closed_lock_with_key
# Skipping (already exists): closed_umbrella
# Skipping (already exists): cloud
# Skipping (already exists): cloud_with_lightning
# Skipping (already exists): cloud_with_lightning_and_rain
# Skipping (already exists): cloud_with_rain
# Skipping (already exists): cloud_with_snow
# Skipping (already exists): clown_face
# Skipping (already exists): clubs
# Skipping (already exists): cn
# Skipping (already exists): coat
# Skipping (already exists): cockroach
# Skipping (already exists): cocktail
# Skipping (already exists): coconut
# Skipping (already exists): cocos_islands
# Skipping (already exists): coffee
# Skipping (already exists): coffin
# Skipping (already exists): coin
# Skipping (already exists): cold_face
# Skipping (already exists): cold_sweat
# Skipping (already exists): collision
# Skipping (already exists): colombia
# Skipping (already exists): comet
# Skipping (already exists): comoros
# Skipping (already exists): compass
# Skipping (already exists): computer
# Skipping (already exists): computer_mouse
# Skipping (already exists): confetti_ball
# Skipping (already exists): confounded
# Skipping (already exists): confused
# Skipping (already exists): congo_brazzaville
# Skipping (already exists): congo_kinshasa
# Skipping (already exists): congratulations
# Skipping (already exists): construction
# Skipping (already exists): construction_worker
# Skipping (already exists): construction_worker_man
# Skipping (already exists): construction_worker_woman
# Skipping (already exists): control_knobs
# Skipping (already exists): convenience_store
# Skipping (already exists): cook
# Skipping (already exists): cook_islands
# Skipping (already exists): cookie
# Skipping (already exists): cool
# Skipping (already exists): cop
# Skipping (already exists): copilot
# Skipping (already exists): copyright
# Skipping (already exists): coral
# Skipping (already exists): corn
# Skipping (already exists): costa_rica
# Skipping (already exists): cote_divoire
# Skipping (already exists): couch_and_lamp
# Skipping (already exists): couple
# Skipping (already exists): couple_with_heart
# Skipping (already exists): couple_with_heart_man_man
# Skipping (already exists): couple_with_heart_woman_man
# Skipping (already exists): couple_with_heart_woman_woman
# Skipping (already exists): couplekiss
# Skipping (already exists): couplekiss_man_man
# Skipping (already exists): couplekiss_man_woman
# Skipping (already exists): couplekiss_woman_woman
# Skipping (already exists): cow
# Skipping (already exists): cow2
# Skipping (already exists): cowboy_hat_face
# Skipping (already exists): crab
# Skipping (already exists): crayon
# Skipping (already exists): credit_card
# Skipping (already exists): crescent_moon
# Skipping (already exists): cricket
# Skipping (already exists): cricket_game
# Skipping (already exists): croatia
# Skipping (already exists): crocodile
# Skipping (already exists): croissant
# Skipping (already exists): crossed_fingers
# Skipping (already exists): crossed_flags
# Skipping (already exists): crossed_swords
# Skipping (already exists): crown
# Skipping (already exists): crutch
# Skipping (already exists): cry
# Skipping (already exists): crying_cat_face
# Skipping (already exists): crystal_ball
# Skipping (already exists): cuba
# Skipping (already exists): cucumber
# Skipping (already exists): cup_with_straw
# Skipping (already exists): cupcake
# Skipping (already exists): cupid
# Skipping (already exists): curacao
# Skipping (already exists): curling_stone
# Skipping (already exists): curly_haired_man
# Skipping (already exists): curly_haired_woman
# Skipping (already exists): curly_loop
# Skipping (already exists): currency_exchange
# Skipping (already exists): curry
# Skipping (already exists): cursing_face
# Skipping (already exists): custard
# Skipping (already exists): customs
# Skipping (already exists): cut_of_meat
# Skipping (already exists): cyclone
# Skipping (already exists): cyprus
# Skipping (already exists): czech_republic
# Skipping (already exists): dagger
# Skipping (already exists): dancer
# Skipping (already exists): dancers
# Skipping (already exists): dancing_men
# Skipping (already exists): dancing_women
# Skipping (already exists): dango
# Skipping (already exists): dark_sunglasses
# Skipping (already exists): dart
# Skipping (already exists): dash
# Skipping (already exists): date
# Skipping (already exists): de
# Skipping (already exists): deaf_man
# Skipping (already exists): deaf_person
# Skipping (already exists): deaf_woman
# Skipping (already exists): deciduous_tree
# Skipping (already exists): deer
# Skipping (already exists): denmark
# Skipping (already exists): department_store
# Skipping (already exists): dependabot
# Skipping (already exists): derelict_house
# Skipping (already exists): desert
# Skipping (already exists): desert_island
# Skipping (already exists): desktop_computer
# Skipping (already exists): detective
# Skipping (already exists): diamond_shape_with_a_dot_inside
# Skipping (already exists): diamonds
# Skipping (already exists): diego_garcia
# Skipping (already exists): disappointed
# Skipping (already exists): disappointed_relieved
# Skipping (already exists): disguised_face
# Skipping (already exists): diving_mask
# Skipping (already exists): diya_lamp
# Skipping (already exists): dizzy
# Skipping (already exists): dizzy_face
# Skipping (already exists): djibouti
# Skipping (already exists): dna
# Skipping (already exists): do_not_litter
# Skipping (already exists): dodo
# Skipping (already exists): dog
# Skipping (already exists): dog2
# Skipping (already exists): dollar
# Skipping (already exists): dolls
# Skipping (already exists): dolphin
# Skipping (already exists): dominica
# Skipping (already exists): dominican_republic
# Skipping (already exists): donkey
# Skipping (already exists): door
# Skipping (already exists): dotted_line_face
# Skipping (already exists): doughnut
# Skipping (already exists): dove
# Skipping (already exists): dragon
# Skipping (already exists): dragon_face
# Skipping (already exists): dress
# Skipping (already exists): dromedary_camel
# Skipping (already exists): drooling_face
# Skipping (already exists): drop_of_blood
# Skipping (already exists): droplet
# Skipping (already exists): drum
# Skipping (already exists): duck
# Skipping (already exists): dumpling
# Skipping (already exists): dvd
# Skipping (already exists): e-mail
# Skipping (already exists): eagle
# Skipping (already exists): ear
# Skipping (already exists): ear_of_rice
# Skipping (already exists): ear_with_hearing_aid
# Skipping (already exists): earth_africa
# Skipping (already exists): earth_americas
# Skipping (already exists): earth_asia
# Skipping (already exists): ecuador
# Skipping (already exists): egg
# Skipping (already exists): eggplant
# Skipping (already exists): egypt
# Skipping (already exists): eight
# Skipping (already exists): eight_pointed_black_star
# Skipping (already exists): eight_spoked_asterisk
# Skipping (already exists): eject_button
# Skipping (already exists): el_salvador
# Skipping (already exists): electric_plug
# Skipping (already exists): electron
# Skipping (already exists): elephant
# Skipping (already exists): elevator
# Skipping (already exists): elf
# Skipping (already exists): elf_man
# Skipping (already exists): elf_woman
# Skipping (already exists): email
# Skipping (already exists): empty_nest
# Skipping (already exists): end
# Skipping (already exists): england
# Skipping (already exists): envelope
# Skipping (already exists): envelope_with_arrow
# Skipping (already exists): equatorial_guinea
# Skipping (already exists): eritrea
# Skipping (already exists): es
# Skipping (already exists): estonia
# Skipping (already exists): ethiopia
# Skipping (already exists): eu
# Skipping (already exists): euro
# Skipping (already exists): european_castle
# Skipping (already exists): european_post_office
# Skipping (already exists): european_union
# Skipping (already exists): evergreen_tree
# Skipping (already exists): exclamation
# Skipping (already exists): exploding_head
# Skipping (already exists): expressionless
# Skipping (already exists): eye
# Skipping (already exists): eye_speech_bubble
# Skipping (already exists): eyeglasses
# Skipping (already exists): eyes
# Skipping (already exists): face_exhaling
# Skipping (already exists): face_holding_back_tears
# Skipping (already exists): face_in_clouds
# Skipping (already exists): face_with_diagonal_mouth
# Skipping (already exists): face_with_head_bandage
# Skipping (already exists): face_with_open_eyes_and_hand_over_mouth
# Skipping (already exists): face_with_peeking_eye
# Skipping (already exists): face_with_spiral_eyes
# Skipping (already exists): face_with_thermometer
# Skipping (already exists): facepalm
# Skipping (already exists): facepunch
# Skipping (already exists): factory
# Skipping (already exists): factory_worker
# Skipping (already exists): fairy
# Skipping (already exists): fairy_man
# Skipping (already exists): fairy_woman
# Skipping (already exists): falafel
# Skipping (already exists): falkland_islands
# Skipping (already exists): fallen_leaf
# Skipping (already exists): family
# Skipping (already exists): family_man_boy
# Skipping (already exists): family_man_boy_boy
# Skipping (already exists): family_man_girl
# Skipping (already exists): family_man_girl_boy
# Skipping (already exists): family_man_girl_girl
# Skipping (already exists): family_man_man_boy
# Skipping (already exists): family_man_man_boy_boy
# Skipping (already exists): family_man_man_girl
# Skipping (already exists): family_man_man_girl_boy
# Skipping (already exists): family_man_man_girl_girl
# Skipping (already exists): family_man_woman_boy
# Skipping (already exists): family_man_woman_boy_boy
# Skipping (already exists): family_man_woman_girl
# Skipping (already exists): family_man_woman_girl_boy
# Skipping (already exists): family_man_woman_girl_girl
# Skipping (already exists): family_woman_boy
# Skipping (already exists): family_woman_boy_boy
# Skipping (already exists): family_woman_girl
# Skipping (already exists): family_woman_girl_boy
# Skipping (already exists): family_woman_girl_girl
# Skipping (already exists): family_woman_woman_boy
# Skipping (already exists): family_woman_woman_boy_boy
# Skipping (already exists): family_woman_woman_girl
# Skipping (already exists): family_woman_woman_girl_boy
# Skipping (already exists): family_woman_woman_girl_girl
# Skipping (already exists): farmer
# Skipping (already exists): faroe_islands
# Skipping (already exists): fast_forward
# Skipping (already exists): fax
# Skipping (already exists): fearful
# Skipping (already exists): feather
# Skipping (already exists): feelsgood
# Skipping (already exists): feet
# Skipping (already exists): female_detective
# Skipping (already exists): female_sign
# Skipping (already exists): ferris_wheel
# Skipping (already exists): ferry
# Skipping (already exists): field_hockey
# Skipping (already exists): fiji
# Skipping (already exists): file_cabinet
# Skipping (already exists): file_folder
# Skipping (already exists): film_projector
# Skipping (already exists): film_strip
# Skipping (already exists): finland
# Skipping (already exists): finnadie
# Skipping (already exists): fire
# Skipping (already exists): fire_engine
# Skipping (already exists): fire_extinguisher
# Skipping (already exists): firecracker
# Skipping (already exists): firefighter
# Skipping (already exists): fireworks
# Skipping (already exists): first_quarter_moon
# Skipping (already exists): first_quarter_moon_with_face
# Skipping (already exists): fish
# Skipping (already exists): fish_cake
# Skipping (already exists): fishing_pole_and_fish
# Skipping (already exists): fishsticks
# Skipping (already exists): fist
# Skipping (already exists): fist_left
# Skipping (already exists): fist_oncoming
# Skipping (already exists): fist_raised
# Skipping (already exists): fist_right
# Skipping (already exists): five
# Skipping (already exists): flags
# Skipping (already exists): flamingo
# Skipping (already exists): flashlight
# Skipping (already exists): flat_shoe
# Skipping (already exists): flatbread
# Skipping (already exists): fleur_de_lis
# Skipping (already exists): flight_arrival
# Skipping (already exists): flight_departure
# Skipping (already exists): flipper
# Skipping (already exists): floppy_disk
# Skipping (already exists): flower_playing_cards
# Skipping (already exists): flushed
# Skipping (already exists): flute
# Skipping (already exists): fly
# Skipping (already exists): flying_disc
# Skipping (already exists): flying_saucer
# Skipping (already exists): fog
# Skipping (already exists): foggy
# Skipping (already exists): folding_hand_fan
# Skipping (already exists): fondue
# Skipping (already exists): foot
# Skipping (already exists): football
# Skipping (already exists): footprints
# Skipping (already exists): fork_and_knife
# Skipping (already exists): fortune_cookie
# Skipping (already exists): fountain
# Skipping (already exists): fountain_pen
# Skipping (already exists): four
# Skipping (already exists): four_leaf_clover
# Skipping (already exists): fox_face
# Skipping (already exists): fr
# Skipping (already exists): framed_picture
# Skipping (already exists): free
# Skipping (already exists): french_guiana
# Skipping (already exists): french_polynesia
# Skipping (already exists): french_southern_territories
# Skipping (already exists): fried_egg
# Skipping (already exists): fried_shrimp
# Skipping (already exists): fries
# Skipping (already exists): frog
# Skipping (already exists): frowning
# Skipping (already exists): frowning_face
# Skipping (already exists): frowning_man
# Skipping (already exists): frowning_person
# Skipping (already exists): frowning_woman
# Skipping (already exists): fu
# Skipping (already exists): fuelpump
# Skipping (already exists): full_moon
# Skipping (already exists): full_moon_with_face
# Skipping (already exists): funeral_urn
# Skipping (already exists): gabon
# Skipping (already exists): gambia
# Skipping (already exists): game_die
# Skipping (already exists): garlic
# Skipping (already exists): gb
# Skipping (already exists): gear
# Skipping (already exists): gem
# Skipping (already exists): gemini
# Skipping (already exists): genie
# Skipping (already exists): genie_man
# Skipping (already exists): genie_woman
# Skipping (already exists): georgia
# Skipping (already exists): ghana
# Skipping (already exists): ghost
# Skipping (already exists): gibraltar
# Skipping (already exists): gift
# Skipping (already exists): gift_heart
# Skipping (already exists): ginger_root
# Skipping (already exists): giraffe
# Skipping (already exists): girl
# Skipping (already exists): globe_with_meridians
# Skipping (already exists): gloves
# Skipping (already exists): goal_net
# Skipping (already exists): goat
# Skipping (already exists): goberserk
# Skipping (already exists): godmode
# Skipping (already exists): goggles
# Skipping (already exists): golf
# Skipping (already exists): golfing
# Skipping (already exists): golfing_man
# Skipping (already exists): golfing_woman
# Skipping (already exists): goose
# Skipping (already exists): gorilla
# Skipping (already exists): grapes
# Skipping (already exists): greece
# Skipping (already exists): green_apple
# Skipping (already exists): green_book
# Skipping (already exists): green_circle
# Skipping (already exists): green_heart
# Skipping (already exists): green_salad
# Skipping (already exists): green_square
# Skipping (already exists): greenland
# Skipping (already exists): grenada
# Skipping (already exists): grey_exclamation
# Skipping (already exists): grey_heart
# Skipping (already exists): grey_question
# Skipping (already exists): grimacing
# Skipping (already exists): grin
# Skipping (already exists): grinning
# Skipping (already exists): guadeloupe
# Skipping (already exists): guam
# Skipping (already exists): guard
# Skipping (already exists): guardsman
# Skipping (already exists): guardswoman
# Skipping (already exists): guatemala
# Skipping (already exists): guernsey
# Skipping (already exists): guide_dog
# Skipping (already exists): guinea
# Skipping (already exists): guinea_bissau
# Skipping (already exists): guitar
# Skipping (already exists): gun
# Skipping (already exists): guyana
# Skipping (already exists): hair_pick
# Skipping (already exists): haircut
# Skipping (already exists): haircut_man
# Skipping (already exists): haircut_woman
# Skipping (already exists): haiti
# Skipping (already exists): hamburger
# Skipping (already exists): hammer
# Skipping (already exists): hammer_and_pick
# Skipping (already exists): hammer_and_wrench
# Skipping (already exists): hamsa
# Skipping (already exists): hamster
# Skipping (already exists): hand
# Skipping (already exists): hand_over_mouth
# Skipping (already exists): hand_with_index_finger_and_thumb_crossed
# Skipping (already exists): handbag
# Skipping (already exists): handball_person
# Skipping (already exists): handshake
# Skipping (already exists): hankey
# Skipping (already exists): hash
# Skipping (already exists): hatched_chick
# Skipping (already exists): hatching_chick
# Skipping (already exists): headphones
# Skipping (already exists): headstone
# Skipping (already exists): health_worker
# Skipping (already exists): hear_no_evil
# Skipping (already exists): heard_mcdonald_islands
# Skipping (already exists): heart
# Skipping (already exists): heart_decoration
# Skipping (already exists): heart_eyes
# Skipping (already exists): heart_eyes_cat
# Skipping (already exists): heart_hands
# Skipping (already exists): heart_on_fire
# Skipping (already exists): heartbeat
# Skipping (already exists): heartpulse
# Skipping (already exists): hearts
# Skipping (already exists): heavy_check_mark
# Skipping (already exists): heavy_division_sign
# Skipping (already exists): heavy_dollar_sign
# Skipping (already exists): heavy_equals_sign
# Skipping (already exists): heavy_exclamation_mark
# Skipping (already exists): heavy_heart_exclamation
# Skipping (already exists): heavy_minus_sign
# Skipping (already exists): heavy_multiplication_x
# Skipping (already exists): heavy_plus_sign
# Skipping (already exists): hedgehog
# Skipping (already exists): helicopter
# Skipping (already exists): herb
# Skipping (already exists): hibiscus
# Skipping (already exists): high_brightness
# Skipping (already exists): high_heel
# Skipping (already exists): hiking_boot
# Skipping (already exists): hindu_temple
# Skipping (already exists): hippopotamus
# Skipping (already exists): hocho
# Skipping (already exists): hole
# Skipping (already exists): honduras
# Skipping (already exists): honey_pot
# Skipping (already exists): honeybee
# Skipping (already exists): hong_kong
# Skipping (already exists): hook
# Skipping (already exists): horse
# Skipping (already exists): horse_racing
# Skipping (already exists): hospital
# Skipping (already exists): hot_face
# Skipping (already exists): hot_pepper
# Skipping (already exists): hotdog
# Skipping (already exists): hotel
# Skipping (already exists): hotsprings
# Skipping (already exists): hourglass
# Skipping (already exists): hourglass_flowing_sand
# Skipping (already exists): house
# Skipping (already exists): house_with_garden
# Skipping (already exists): houses
# Skipping (already exists): hugs
# Skipping (already exists): hungary
# Skipping (already exists): hurtrealbad
# Skipping (already exists): hushed
# Skipping (already exists): hut
# Skipping (already exists): hyacinth
# Skipping (already exists): ice_cream
# Skipping (already exists): ice_cube
# Skipping (already exists): ice_hockey
# Skipping (already exists): ice_skate
# Skipping (already exists): icecream
# Skipping (already exists): iceland
# Skipping (already exists): id
# Skipping (already exists): identification_card
# Skipping (already exists): ideograph_advantage
# Skipping (already exists): imp
# Skipping (already exists): inbox_tray
# Skipping (already exists): incoming_envelope
# Skipping (already exists): index_pointing_at_the_viewer
# Skipping (already exists): india
# Skipping (already exists): indonesia
# Skipping (already exists): infinity
# Skipping (already exists): information_desk_person
# Skipping (already exists): information_source
# Skipping (already exists): innocent
# Skipping (already exists): interrobang
# Skipping (already exists): iphone
# Skipping (already exists): iran
# Skipping (already exists): iraq
# Skipping (already exists): ireland
# Skipping (already exists): isle_of_man
# Skipping (already exists): israel
# Skipping (already exists): it
# Skipping (already exists): izakaya_lantern
# Skipping (already exists): jack_o_lantern
# Skipping (already exists): jamaica
# Skipping (already exists): japan
# Skipping (already exists): japanese_castle
# Skipping (already exists): japanese_goblin
# Skipping (already exists): japanese_ogre
# Skipping (already exists): jar
# Skipping (already exists): jeans
# Skipping (already exists): jellyfish
# Skipping (already exists): jersey
# Skipping (already exists): jigsaw
# Skipping (already exists): jordan
# Skipping (already exists): joy
# Skipping (already exists): joy_cat
# Skipping (already exists): joystick
# Skipping (already exists): jp
# Skipping (already exists): judge
# Skipping (already exists): juggling_person
# Skipping (already exists): kaaba
# Skipping (already exists): kangaroo
# Skipping (already exists): kazakhstan
# Skipping (already exists): kenya
# Skipping (already exists): key
# Skipping (already exists): keyboard
# Skipping (already exists): keycap_ten
# Skipping (already exists): khanda
# Skipping (already exists): kick_scooter
# Skipping (already exists): kimono
# Skipping (already exists): kiribati
# Skipping (already exists): kiss
# Skipping (already exists): kissing
# Skipping (already exists): kissing_cat
# Skipping (already exists): kissing_closed_eyes
# Skipping (already exists): kissing_heart
# Skipping (already exists): kissing_smiling_eyes
# Skipping (already exists): kite
# Skipping (already exists): kiwi_fruit
# Skipping (already exists): kneeling_man
# Skipping (already exists): kneeling_person
# Skipping (already exists): kneeling_woman
# Skipping (already exists): knife
# Skipping (already exists): knot
# Skipping (already exists): koala
# Skipping (already exists): koko
# Skipping (already exists): kosovo
# Skipping (already exists): kr
# Skipping (already exists): kuwait
# Skipping (already exists): kyrgyzstan
# Skipping (already exists): lab_coat
# Skipping (already exists): label
# Skipping (already exists): lacrosse
# Skipping (already exists): ladder
# Skipping (already exists): lady_beetle
# Skipping (already exists): lantern
# Skipping (already exists): laos
# Skipping (already exists): large_blue_circle
# Skipping (already exists): large_blue_diamond
# Skipping (already exists): large_orange_diamond
# Skipping (already exists): last_quarter_moon
# Skipping (already exists): last_quarter_moon_with_face
# Skipping (already exists): latin_cross
# Skipping (already exists): latvia
# Skipping (already exists): laughing
# Skipping (already exists): leafy_green
# Skipping (already exists): leaves
# Skipping (already exists): lebanon
# Skipping (already exists): ledger
# Skipping (already exists): left_luggage
# Skipping (already exists): left_right_arrow
# Skipping (already exists): left_speech_bubble
# Skipping (already exists): leftwards_arrow_with_hook
# Skipping (already exists): leftwards_hand
# Skipping (already exists): leftwards_pushing_hand
# Skipping (already exists): leg
# Skipping (already exists): lemon
# Skipping (already exists): leo
# Skipping (already exists): leopard
# Skipping (already exists): lesotho
# Skipping (already exists): level_slider
# Skipping (already exists): liberia
# Skipping (already exists): libra
# Skipping (already exists): libya
# Skipping (already exists): liechtenstein
# Skipping (already exists): light_blue_heart
# Skipping (already exists): light_rail
# Skipping (already exists): link
# Skipping (already exists): lion
# Skipping (already exists): lips
# Skipping (already exists): lipstick
# Skipping (already exists): lithuania
# Skipping (already exists): lizard
# Skipping (already exists): llama
# Skipping (already exists): lobster
# Skipping (already exists): lock
# Skipping (already exists): lock_with_ink_pen
# Skipping (already exists): lollipop
# Skipping (already exists): long_drum
# Skipping (already exists): loop
# Skipping (already exists): lotion_bottle
# Skipping (already exists): lotus
# Skipping (already exists): lotus_position
# Skipping (already exists): lotus_position_man
# Skipping (already exists): lotus_position_woman
# Skipping (already exists): loud_sound
# Skipping (already exists): loudspeaker
# Skipping (already exists): love_hotel
# Skipping (already exists): love_letter
# Skipping (already exists): love_you_gesture
# Skipping (already exists): low_battery
# Skipping (already exists): low_brightness
# Skipping (already exists): luggage
# Skipping (already exists): lungs
# Skipping (already exists): luxembourg
# Skipping (already exists): lying_face
# Skipping (already exists): m
# Skipping (already exists): macau
# Skipping (already exists): macedonia
# Skipping (already exists): madagascar
# Skipping (already exists): mag
# Skipping (already exists): mag_right
# Skipping (already exists): mage
# Skipping (already exists): mage_man
# Skipping (already exists): mage_woman
# Skipping (already exists): magic_wand
# Skipping (already exists): magnet
# Skipping (already exists): mahjong
# Skipping (already exists): mailbox
# Skipping (already exists): mailbox_closed
# Skipping (already exists): mailbox_with_mail
# Skipping (already exists): mailbox_with_no_mail
# Skipping (already exists): malawi
# Skipping (already exists): malaysia
# Skipping (already exists): maldives
# Skipping (already exists): male_detective
# Skipping (already exists): male_sign
# Skipping (already exists): mali
# Skipping (already exists): malta
# Skipping (already exists): mammoth
# Skipping (already exists): man
# Skipping (already exists): man_artist
# Skipping (already exists): man_astronaut
# Skipping (already exists): man_beard
# Skipping (already exists): man_cartwheeling
# Skipping (already exists): man_cook
# Skipping (already exists): man_dancing
# Skipping (already exists): man_facepalming
# Skipping (already exists): man_factory_worker
# Skipping (already exists): man_farmer
# Skipping (already exists): man_feeding_baby
# Skipping (already exists): man_firefighter
# Skipping (already exists): man_health_worker
# Skipping (already exists): man_in_manual_wheelchair
# Skipping (already exists): man_in_motorized_wheelchair
# Skipping (already exists): man_in_tuxedo
# Skipping (already exists): man_judge
# Skipping (already exists): man_juggling
# Skipping (already exists): man_mechanic
# Skipping (already exists): man_office_worker
# Skipping (already exists): man_pilot
# Skipping (already exists): man_playing_handball
# Skipping (already exists): man_playing_water_polo
# Skipping (already exists): man_scientist
# Skipping (already exists): man_shrugging
# Skipping (already exists): man_singer
# Skipping (already exists): man_student
# Skipping (already exists): man_teacher
# Skipping (already exists): man_technologist
# Skipping (already exists): man_with_gua_pi_mao
# Skipping (already exists): man_with_probing_cane
# Skipping (already exists): man_with_turban
# Skipping (already exists): man_with_veil
# Skipping (already exists): mandarin
# Skipping (already exists): mango
# Skipping (already exists): mans_shoe
# Skipping (already exists): mantelpiece_clock
# Skipping (already exists): manual_wheelchair
# Skipping (already exists): maple_leaf
# Skipping (already exists): maracas
# Skipping (already exists): marshall_islands
# Skipping (already exists): martial_arts_uniform
# Skipping (already exists): martinique
# Skipping (already exists): mask
# Skipping (already exists): massage
# Skipping (already exists): massage_man
# Skipping (already exists): massage_woman
# Skipping (already exists): mate
# Skipping (already exists): mauritania
# Skipping (already exists): mauritius
# Skipping (already exists): mayotte
# Skipping (already exists): meat_on_bone
# Skipping (already exists): mechanic
# Skipping (already exists): mechanical_arm
# Skipping (already exists): mechanical_leg
# Skipping (already exists): medal_military
# Skipping (already exists): medal_sports
# Skipping (already exists): medical_symbol
# Skipping (already exists): mega
# Skipping (already exists): melon
# Skipping (already exists): melting_face
# Skipping (already exists): memo
# Skipping (already exists): men_wrestling
# Skipping (already exists): mending_heart
# Skipping (already exists): menorah
# Skipping (already exists): mens
# Skipping (already exists): mermaid
# Skipping (already exists): merman
# Skipping (already exists): merperson
# Skipping (already exists): metal
# Skipping (already exists): metro
# Skipping (already exists): mexico
# Skipping (already exists): microbe
# Skipping (already exists): micronesia
# Skipping (already exists): microphone
# Skipping (already exists): microscope
# Skipping (already exists): middle_finger
# Skipping (already exists): military_helmet
# Skipping (already exists): milk_glass
# Skipping (already exists): milky_way
# Skipping (already exists): minibus
# Skipping (already exists): minidisc
# Skipping (already exists): mirror
# Skipping (already exists): mirror_ball
# Skipping (already exists): mobile_phone_off
# Skipping (already exists): moldova
# Skipping (already exists): monaco
# Skipping (already exists): money_mouth_face
# Skipping (already exists): money_with_wings
# Skipping (already exists): moneybag
# Skipping (already exists): mongolia
# Skipping (already exists): monkey
# Skipping (already exists): monkey_face
# Skipping (already exists): monocle_face
# Skipping (already exists): monorail
# Skipping (already exists): montenegro
# Skipping (already exists): montserrat
# Skipping (already exists): moon
# Skipping (already exists): moon_cake
# Skipping (already exists): moose
# Skipping (already exists): morocco
# Skipping (already exists): mortar_board
# Skipping (already exists): mosque
# Skipping (already exists): mosquito
# Skipping (already exists): motor_boat
# Skipping (already exists): motor_scooter
# Skipping (already exists): motorcycle
# Skipping (already exists): motorized_wheelchair
# Skipping (already exists): motorway
# Skipping (already exists): mount_fuji
# Skipping (already exists): mountain
# Skipping (already exists): mountain_bicyclist
# Skipping (already exists): mountain_biking_man
# Skipping (already exists): mountain_biking_woman
# Skipping (already exists): mountain_cableway
# Skipping (already exists): mountain_railway
# Skipping (already exists): mountain_snow
# Skipping (already exists): mouse
# Skipping (already exists): mouse2
# Skipping (already exists): mouse_trap
# Skipping (already exists): movie_camera
# Skipping (already exists): moyai
# Skipping (already exists): mozambique
# Skipping (already exists): mrs_claus
# Skipping (already exists): muscle
# Skipping (already exists): mushroom
# Skipping (already exists): musical_keyboard
# Skipping (already exists): musical_note
# Skipping (already exists): musical_score
# Skipping (already exists): mute
# Skipping (already exists): mx_claus
# Skipping (already exists): myanmar
# Skipping (already exists): nail_care
# Skipping (already exists): name_badge
# Skipping (already exists): namibia
# Skipping (already exists): national_park
# Skipping (already exists): nauru
# Skipping (already exists): nauseated_face
# Skipping (already exists): nazar_amulet
# Skipping (already exists): neckbeard
# Skipping (already exists): necktie
# Skipping (already exists): negative_squared_cross_mark
# Skipping (already exists): nepal
# Skipping (already exists): nerd_face
# Skipping (already exists): nest_with_eggs
# Skipping (already exists): nesting_dolls
# Skipping (already exists): netherlands
# Skipping (already exists): neutral_face
# Skipping (already exists): new
# Skipping (already exists): new_caledonia
# Skipping (already exists): new_moon
# Skipping (already exists): new_moon_with_face
# Skipping (already exists): new_zealand
# Skipping (already exists): newspaper
# Skipping (already exists): newspaper_roll
# Skipping (already exists): next_track_button
# Skipping (already exists): ng
# Skipping (already exists): ng_man
# Skipping (already exists): ng_woman
# Skipping (already exists): nicaragua
# Skipping (already exists): niger
# Skipping (already exists): nigeria
# Skipping (already exists): night_with_stars
# Skipping (already exists): nine
# Skipping (already exists): ninja
# Skipping (already exists): niue
# Skipping (already exists): no_bell
# Skipping (already exists): no_bicycles
# Skipping (already exists): no_entry
# Skipping (already exists): no_entry_sign
# Skipping (already exists): no_good
# Skipping (already exists): no_good_man
# Skipping (already exists): no_good_woman
# Skipping (already exists): no_mobile_phones
# Skipping (already exists): no_mouth
# Skipping (already exists): no_pedestrians
# Skipping (already exists): no_smoking
# Skipping (already exists): non-potable_water
# Skipping (already exists): norfolk_island
# Skipping (already exists): north_korea
# Skipping (already exists): northern_mariana_islands
# Skipping (already exists): norway
# Skipping (already exists): nose
# Skipping (already exists): notebook
# Skipping (already exists): notebook_with_decorative_cover
# Skipping (already exists): notes
# Skipping (already exists): nut_and_bolt
# Skipping (already exists): o
# Skipping (already exists): o2
# Skipping (already exists): ocean
# Skipping (already exists): octocat
# Skipping (already exists): octopus
# Skipping (already exists): oden
# Skipping (already exists): office
# Skipping (already exists): office_worker
# Skipping (already exists): oil_drum
# Skipping (already exists): ok
# Skipping (already exists): ok_hand
# Skipping (already exists): ok_man
# Skipping (already exists): ok_person
# Skipping (already exists): ok_woman
# Skipping (already exists): old_key
# Skipping (already exists): older_adult
# Skipping (already exists): older_man
# Skipping (already exists): older_woman
# Skipping (already exists): olive
# Skipping (already exists): om
# Skipping (already exists): oman
# Skipping (already exists): on
# Skipping (already exists): oncoming_automobile
# Skipping (already exists): oncoming_bus
# Skipping (already exists): oncoming_police_car
# Skipping (already exists): oncoming_taxi
# Skipping (already exists): one
# Skipping (already exists): one_piece_swimsuit
# Skipping (already exists): onion
# Skipping (already exists): open_book
# Skipping (already exists): open_file_folder
# Skipping (already exists): open_hands
# Skipping (already exists): open_mouth
# Skipping (already exists): open_umbrella
# Skipping (already exists): ophiuchus
# Skipping (already exists): orange
# Skipping (already exists): orange_book
# Skipping (already exists): orange_circle
# Skipping (already exists): orange_heart
# Skipping (already exists): orange_square
# Skipping (already exists): orangutan
# Skipping (already exists): orthodox_cross
# Skipping (already exists): otter
# Skipping (already exists): outbox_tray
# Skipping (already exists): owl
# Skipping (already exists): ox
# Skipping (already exists): oyster
# Skipping (already exists): package
# Skipping (already exists): page_facing_up
# Skipping (already exists): page_with_curl
# Skipping (already exists): pager
# Skipping (already exists): paintbrush
# Skipping (already exists): pakistan
# Skipping (already exists): palau
# Skipping (already exists): palestinian_territories
# Skipping (already exists): palm_down_hand
# Skipping (already exists): palm_tree
# Skipping (already exists): palm_up_hand
# Skipping (already exists): palms_up_together
# Skipping (already exists): panama
# Skipping (already exists): pancakes
# Skipping (already exists): panda_face
# Skipping (already exists): paperclip
# Skipping (already exists): paperclips
# Skipping (already exists): papua_new_guinea
# Skipping (already exists): parachute
# Skipping (already exists): paraguay
# Skipping (already exists): parasol_on_ground
# Skipping (already exists): parking
# ...
# Skipping (already exists): shower
# Skipping (already exists): shrimp
# Skipping (already exists): shrug
# Skipping (already exists): shushing_face
# Skipping (already exists): sierra_leone
# Skipping (already exists): signal_strength
# Skipping (already exists): singapore
# Skipping (already exists): singer
# Skipping (already exists): sint_maarten
# Skipping (already exists): six
# Skipping (already exists): six_pointed_star
# Skipping (already exists): skateboard
# Skipping (already exists): ski
# Skipping (already exists): skier
# Skipping (already exists): skull
# Skipping (already exists): skull_and_crossbones
# Skipping (already exists): skunk
# Skipping (already exists): sled
# Skipping (already exists): sleeping
# Skipping (already exists): sleeping_bed
# Skipping (already exists): sleepy
# Skipping (already exists): slightly_frowning_face
# Skipping (already exists): slightly_smiling_face
# Skipping (already exists): slot_machine
# Skipping (already exists): sloth
# Skipping (already exists): slovakia
# Skipping (already exists): slovenia
# Skipping (already exists): small_airplane
# Skipping (already exists): small_blue_diamond
# Skipping (already exists): small_orange_diamond
# Skipping (already exists): small_red_triangle
# Skipping (already exists): small_red_triangle_down
# Skipping (already exists): smile
# Skipping (already exists): smile_cat
# Skipping (already exists): smiley
# Skipping (already exists): smiley_cat
# Skipping (already exists): smiling_face_with_tear
# Skipping (already exists): smiling_face_with_three_hearts
# Skipping (already exists): smiling_imp
# Skipping (already exists): smirk
# Skipping (already exists): smirk_cat
# Skipping (already exists): smoking
# Skipping (already exists): snail
# Skipping (already exists): snake
# Skipping (already exists): sneezing_face
# Skipping (already exists): snowboarder
# Skipping (already exists): snowflake
# Skipping (already exists): snowman
# Skipping (already exists): snowman_with_snow
# Skipping (already exists): soap
# Skipping (already exists): sob
# Skipping (already exists): soccer
# Skipping (already exists): socks
# Skipping (already exists): softball
# Skipping (already exists): solomon_islands
# Skipping (already exists): somalia
# Skipping (already exists): soon
# Skipping (already exists): sos
# Skipping (already exists): sound
# Skipping (already exists): south_africa
# Skipping (already exists): south_georgia_south_sandwich_islands
# Skipping (already exists): south_sudan
# Skipping (already exists): space_invader
# Skipping (already exists): spades
# Skipping (already exists): spaghetti
# Skipping (already exists): sparkle
# Skipping (already exists): sparkler
# Skipping (already exists): sparkles
# Skipping (already exists): sparkling_heart
# Skipping (already exists): speak_no_evil
# Skipping (already exists): speaker
# Skipping (already exists): speaking_head
# Skipping (already exists): speech_balloon
# Skipping (already exists): speedboat
# Skipping (already exists): spider
# Skipping (already exists): spider_web
# Skipping (already exists): spiral_calendar
# Skipping (already exists): spiral_notepad
# Skipping (already exists): sponge
# Skipping (already exists): spoon
# Skipping (already exists): squid
# Skipping (already exists): sri_lanka
# Skipping (already exists): st_barthelemy
# Skipping (already exists): st_helena
# Skipping (already exists): st_kitts_nevis
# Skipping (already exists): st_lucia
# Skipping (already exists): st_martin
# Skipping (already exists): st_pierre_miquelon
# Skipping (already exists): st_vincent_grenadines
# Skipping (already exists): stadium
# Skipping (already exists): standing_man
# Skipping (already exists): standing_person
# Skipping (already exists): standing_woman
# Skipping (already exists): star
# Skipping (already exists): star2
# Skipping (already exists): star_and_crescent
# Skipping (already exists): star_of_david
# Skipping (already exists): star_struck
# Skipping (already exists): stars
# Skipping (already exists): station
# Skipping (already exists): statue_of_liberty
# Skipping (already exists): steam_locomotive
# Skipping (already exists): stethoscope
# Skipping (already exists): stew
# Skipping (already exists): stop_button
# Skipping (already exists): stop_sign
# Skipping (already exists): stopwatch
# Skipping (already exists): straight_ruler
# Skipping (already exists): strawberry
# Skipping (already exists): stuck_out_tongue
# Skipping (already exists): stuck_out_tongue_closed_eyes
# Skipping (already exists): stuck_out_tongue_winking_eye
# Skipping (already exists): student
# Skipping (already exists): studio_microphone
# Skipping (already exists): stuffed_flatbread
# Skipping (already exists): sudan
# Skipping (already exists): sun_behind_large_cloud
# Skipping (already exists): sun_behind_rain_cloud
# Skipping (already exists): sun_behind_small_cloud
# Skipping (already exists): sun_with_face
# Skipping (already exists): sunflower
# Skipping (already exists): sunglasses
# Skipping (already exists): sunny
# Skipping (already exists): sunrise
# Skipping (already exists): sunrise_over_mountains
# Skipping (already exists): superhero
# Skipping (already exists): superhero_man
# Skipping (already exists): superhero_woman
# Skipping (already exists): supervillain
# Skipping (already exists): supervillain_man
# Skipping (already exists): supervillain_woman
# Skipping (already exists): surfer
# Skipping (already exists): surfing_man
# Skipping (already exists): surfing_woman
# Skipping (already exists): suriname
# Skipping (already exists): sushi
# Skipping (already exists): suspect
# Skipping (already exists): suspension_railway
# Skipping (already exists): svalbard_jan_mayen
# Skipping (already exists): swan
# Skipping (already exists): swaziland
# Skipping (already exists): sweat
# Skipping (already exists): sweat_drops
# Skipping (already exists): sweat_smile
# Skipping (already exists): sweden
# Skipping (already exists): sweet_potato
# Skipping (already exists): swim_brief
# Skipping (already exists): swimmer
# Skipping (already exists): swimming_man
# Skipping (already exists): swimming_woman
# Skipping (already exists): switzerland
# Skipping (already exists): symbols
# Skipping (already exists): synagogue
# Skipping (already exists): syria
# Skipping (already exists): syringe
# Skipping (already exists): t-rex
# Skipping (already exists): taco
# Skipping (already exists): tada
# Skipping (already exists): taiwan
# Skipping (already exists): tajikistan
# Skipping (already exists): takeout_box
# Skipping (already exists): tamale
# Skipping (already exists): tanabata_tree
# Skipping (already exists): tangerine
# Skipping (already exists): tanzania
# Skipping (already exists): taurus
# Skipping (already exists): taxi
# Skipping (already exists): tea
# Skipping (already exists): teacher
# Skipping (already exists): teapot
# Skipping (already exists): technologist
# Skipping (already exists): teddy_bear
# Skipping (already exists): telephone
# Skipping (already exists): telephone_receiver
# Skipping (already exists): telescope
# Skipping (already exists): tennis
# Skipping (already exists): tent
# Skipping (already exists): test_tube
# Skipping (already exists): thailand
# Skipping (already exists): thermometer
# Skipping (already exists): thinking
# Skipping (already exists): thong_sandal
# Skipping (already exists): thought_balloon
# Skipping (already exists): thread
# Skipping (already exists): three
# Skipping (already exists): thumbsdown
# Skipping (already exists): thumbsup
# Skipping (already exists): ticket
# Skipping (already exists): tickets
# Skipping (already exists): tiger
# Skipping (already exists): tiger2
# Skipping (already exists): timer_clock
# Skipping (already exists): timor_leste
# Skipping (already exists): tipping_hand_man
# Skipping (already exists): tipping_hand_person
# Skipping (already exists): tipping_hand_woman
# Skipping (already exists): tired_face
# Skipping (already exists): tm
# Skipping (already exists): togo
# Skipping (already exists): toilet
# Skipping (already exists): tokelau
# Skipping (already exists): tokyo_tower
# Skipping (already exists): tomato
# Skipping (already exists): tonga
# Skipping (already exists): tongue
# Skipping (already exists): toolbox
# Skipping (already exists): tooth
# Skipping (already exists): toothbrush
# Skipping (already exists): top
# Skipping (already exists): tophat
# Skipping (already exists): tornado
# Skipping (already exists): tr
# Skipping (already exists): trackball
# Skipping (already exists): tractor
# Skipping (already exists): traffic_light
# Skipping (already exists): train
# Skipping (already exists): train2
# Skipping (already exists): tram
# Skipping (already exists): transgender_flag
# Skipping (already exists): transgender_symbol
# Skipping (already exists): triangular_flag_on_post
# Skipping (already exists): triangular_ruler
# Skipping (already exists): trident
# Skipping (already exists): trinidad_tobago
# Skipping (already exists): tristan_da_cunha
# Skipping (already exists): triumph
# Skipping (already exists): troll
# Skipping (already exists): trolleybus
# Skipping (already exists): trollface
# Skipping (already exists): trophy
# Skipping (already exists): tropical_drink
# Skipping (already exists): tropical_fish
# Skipping (already exists): truck
# Skipping (already exists): trumpet
# Skipping (already exists): tshirt
# Skipping (already exists): tulip
# Skipping (already exists): tumbler_glass
# Skipping (already exists): tunisia
# Skipping (already exists): turkey
# Skipping (already exists): turkmenistan
# Skipping (already exists): turks_caicos_islands
# Skipping (already exists): turtle
# Skipping (already exists): tuvalu
# Skipping (already exists): tv
# Skipping (already exists): twisted_rightwards_arrows
# Skipping (already exists): two
# Skipping (already exists): two_hearts
# Skipping (already exists): two_men_holding_hands
# Skipping (already exists): two_women_holding_hands
# Skipping (already exists): u5272
# Skipping (already exists): u5408
# Skipping (already exists): u55b6
# Skipping (already exists): u6307
# Skipping (already exists): u6708
# Skipping (already exists): u6709
# Skipping (already exists): u6e80
# Skipping (already exists): u7121
# Skipping (already exists): u7533
# Skipping (already exists): u7981
# Skipping (already exists): u7a7a
# Skipping (already exists): uganda
# Skipping (already exists): uk
# Skipping (already exists): ukraine
# Skipping (already exists): umbrella
# Skipping (already exists): unamused
# Skipping (already exists): underage
# Skipping (already exists): unicorn
# Skipping (already exists): united_arab_emirates
# Skipping (already exists): united_nations
# Skipping (already exists): unlock
# Skipping (already exists): up
# Skipping (already exists): upside_down_face
# Skipping (already exists): uruguay
# Skipping (already exists): us
# Skipping (already exists): us_outlying_islands
# Skipping (already exists): us_virgin_islands
# Skipping (already exists): uzbekistan
# Skipping (already exists): v
# Skipping (already exists): vampire
# Skipping (already exists): vampire_man
# Skipping (already exists): vampire_woman
# Skipping (already exists): vanuatu
# Skipping (already exists): vatican_city
# Skipping (already exists): venezuela
# Skipping (already exists): vertical_traffic_light
# Skipping (already exists): vhs
# Skipping (already exists): vibration_mode
# Skipping (already exists): video_camera
# Skipping (already exists): video_game
# Skipping (already exists): vietnam
# Skipping (already exists): violin
# Skipping (already exists): virgo
# Skipping (already exists): volcano
# Skipping (already exists): volleyball
# Skipping (already exists): vomiting_face
# Skipping (already exists): vs
# Skipping (already exists): vulcan_salute
# Skipping (already exists): waffle
# Skipping (already exists): wales
# Skipping (already exists): walking
# Skipping (already exists): walking_man
# Skipping (already exists): walking_woman
# Skipping (already exists): wallis_futuna
# Skipping (already exists): waning_crescent_moon
# Skipping (already exists): waning_gibbous_moon
# Skipping (already exists): warning
# Skipping (already exists): wastebasket
# Skipping (already exists): watch
# Skipping (already exists): water_buffalo
# Skipping (already exists): water_polo
# Skipping (already exists): watermelon
# Skipping (already exists): wave
# Skipping (already exists): wavy_dash
# Skipping (already exists): waxing_crescent_moon
# Skipping (already exists): waxing_gibbous_moon
# Skipping (already exists): wc
# Skipping (already exists): weary
# Skipping (already exists): wedding
# Skipping (already exists): weight_lifting
# Skipping (already exists): weight_lifting_man
# Skipping (already exists): weight_lifting_woman
# Skipping (already exists): western_sahara
# Skipping (already exists): whale
# Skipping (already exists): whale2
# Skipping (already exists): wheel
# Skipping (already exists): wheel_of_dharma
# Skipping (already exists): wheelchair
# Skipping (already exists): white_check_mark
# Skipping (already exists): white_circle
# Skipping (already exists): white_flag
# Skipping (already exists): white_flower
# Skipping (already exists): white_haired_man
# Skipping (already exists): white_haired_woman
# Skipping (already exists): white_heart
# Skipping (already exists): white_large_square
# Skipping (already exists): white_medium_small_square
# Skipping (already exists): white_medium_square
# Skipping (already exists): white_small_square
# Skipping (already exists): white_square_button
# Skipping (already exists): wilted_flower
# Skipping (already exists): wind_chime
# Skipping (already exists): wind_face
# Skipping (already exists): window
# Skipping (already exists): wine_glass
# Skipping (already exists): wing
# Skipping (already exists): wink
# Skipping (already exists): wireless
# Skipping (already exists): wolf
# Skipping (already exists): woman
# Skipping (already exists): woman_artist
# Skipping (already exists): woman_astronaut
# Skipping (already exists): woman_beard
# Skipping (already exists): woman_cartwheeling
# Skipping (already exists): woman_cook
# Skipping (already exists): woman_dancing
# Skipping (already exists): woman_facepalming
# Skipping (already exists): woman_factory_worker
# Skipping (already exists): woman_farmer
# Skipping (already exists): woman_feeding_baby
# Skipping (already exists): woman_firefighter
# Skipping (already exists): woman_health_worker
# Skipping (already exists): woman_in_manual_wheelchair
# Skipping (already exists): woman_in_motorized_wheelchair
# Skipping (already exists): woman_in_tuxedo
# Skipping (already exists): woman_judge
# Skipping (already exists): woman_juggling
# Skipping (already exists): woman_mechanic
# Skipping (already exists): woman_office_worker
# Skipping (already exists): woman_pilot
# Skipping (already exists): woman_playing_handball
# Skipping (already exists): woman_playing_water_polo
# Skipping (already exists): woman_scientist
# Skipping (already exists): woman_shrugging
# Skipping (already exists): woman_singer
# Skipping (already exists): woman_student
# Skipping (already exists): woman_teacher
# Skipping (already exists): woman_technologist
# Skipping (already exists): woman_with_headscarf
# Skipping (already exists): woman_with_probing_cane
# Skipping (already exists): woman_with_turban
# Skipping (already exists): woman_with_veil
# Skipping (already exists): womans_clothes
# Skipping (already exists): womans_hat
# Skipping (already exists): women_wrestling
# Skipping (already exists): womens
# Skipping (already exists): wood
# Skipping (already exists): woozy_face
# Skipping (already exists): world_map
# Skipping (already exists): worm
# Skipping (already exists): worried
# Skipping (already exists): wrench
# Skipping (already exists): wrestling
# Skipping (already exists): writing_hand
# Skipping (already exists): x
# Skipping (already exists): x_ray
# Skipping (already exists): yarn
# Skipping (already exists): yawning_face
# Skipping (already exists): yellow_circle
# Skipping (already exists): yellow_heart
# Skipping (already exists): yellow_square
# Skipping (already exists): yemen
# Skipping (already exists): yen
# Skipping (already exists): yin_yang
# Skipping (already exists): yo_yo
# Skipping (already exists): yum
# Skipping (already exists): zambia
# Skipping (already exists): zany_face
# Skipping (already exists): zap
# Skipping (already exists): zebra
# Skipping (already exists): zero
# Skipping (already exists): zimbabwe
# Skipping (already exists): zipper_mouth_face
# Skipping (already exists): zombie
# Skipping (already exists): zombie_man
# Skipping (already exists): zombie_woman
# Skipping (already exists): zzz
